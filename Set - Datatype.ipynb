# %%
thisset = {"apple", "banana", "cherry", "apple"}
print(thisset)
# Out:
# {'banana', 'apple', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}
print(len(thisset))
# Out:
# 3

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {1, 5, 7, 9, 3}
set3 = {True, False, False}
print(set1)
print(set2)
print(set3)
# Out:
# {'banana', 'apple', 'cherry'}
# {1, 3, 5, 7, 9}
# {False, True}

# %%
set1 = {"abc", 34, True, 40, "male"}
print(set1)
# Out:
# {True, 34, 40, 'male', 'abc'}

# %%
myset = {"apple", "banana", "cherry"}
print(type(myset))
# Out:
# <class 'set'>

# %%
thisset = set(("apple", "banana", "cherry"))
print(thisset) #prints in random fashion, since its unordered
# Out:
# {'banana', 'apple', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}
for x in thisset:
  print(x)  #Loop through the set, and print the values
# Out:
# banana
# apple
# cherry

# %%
thisset = {"apple", "banana", "cherry"}
print("banana" in thisset) #Check if value is present in the set
# Out:
# True

# %%
thisset = {"apple", "banana", "cherry"}
print("mango" in thisset) #Check if value is present in the set
# Out:
# False

# %%
thisset = {"apple", "banana", "cherry"}
thisset.add("orange")   #Add an item to a set, using the add() method
print(thisset)
# Out:
# {'banana', 'orange', 'apple', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}
tropical = {"pineapple", "mango", "papaya"}
thisset.update(tropical)  #update the original set, with the new set
print(thisset)
# Out:
# {'banana', 'mango', 'apple', 'papaya', 'cherry', 'pineapple'}

# %%
thisset = {"apple", "banana", "cherry"}
mylist = ["kiwi", "orange"]
thisset.update(mylist)  # update the original set, with values from list
print(thisset)
# Out:
# {'banana', 'orange', 'apple', 'kiwi', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}
thisset.remove("banana")  #Remove method, to remove a value
print(thisset)
# Out:
# {'apple', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}
thisset.discard("banana")  #Remove method, to remove a value
print(thisset)
# Out:
# {'apple', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}
x = thisset.pop()   #pop method removes the last value
print(x) #removed item
print(thisset) #the set after removal
# Out:
# banana
# {'apple', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}
thisset.clear()   #clear() method empties the set
print(thisset)
# Out:
# set()

# %%
thisset = {"apple", "banana", "cherry"}
del thisset   #delete the set
print(thisset) #this will raise an error because the set no longer exists
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-7719ee2047e6> in <module>
#       1 thisset = {"apple", "banana", "cherry"}
#       2 del thisset   #delete the set
# ----> 3 print(thisset) #this will raise an error because the set no longer exists
#
# NameError: name 'thisset' is not defined

# %%
thisset = {"apple", "banana", "cherry"}
for x in thisset:
  print(x)   #Loop through the set, and print the values
# Out:
# banana
# apple
# cherry

# %%
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}
set3 = set1.union(set2)  #Union method to join two sets
print(set3)
# Out:
# {1, 2, 3, 'a', 'c', 'b'}

# %%
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}
set1.update(set2)   #update method to update the value of 1st by 2nd set
print(set1)
# Out:
# {1, 2, 3, 'a', 'c', 'b'}

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}
x.intersection_update(y)  #keep the values that exist in both sets
print(x)
# Out:
# {'apple'}

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}
z = x.intersection(y)  #Return a set that contains the items that exist in both sets
print(z)
# Out:
# {'apple'}

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}
x.symmetric_difference_update(y)  #Keep the items that are not present in both sets
print(x)
# Out:
# {'banana', 'google', 'cherry', 'microsoft'}

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}
z = x.symmetric_difference(y)  #Return a set that contains all items from both sets
print(z)
# Out:
# {'banana', 'google', 'cherry', 'microsoft'}
