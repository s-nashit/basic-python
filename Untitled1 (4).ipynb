# %%
import pandas as pd
df2 = pd.read_csv('marks.csv')
df2.head(1)
# Out:
#             Name  English  Hindi  Maths  Science  Social Science
# 0  Smriti Ranjan       85     83     93       91            94.0

# %%
df2['total']=df2['English']+df2['Hindi']+df2['Maths']+df2['Science']

# %%
df2
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science  \
# 0          Smriti Ranjan       85     83     93       91            94.0
# 1         Tannu kumari..       90     75     78       73            75.0
# 2                  Seema       93     75     78       89            94.0
# 3        Mukesh Nirmal..       92     71     72       87            78.0
# 4                  rohit       75     78     87       90            87.0
# 5               Ramakant       84     76     75       76            96.0
# 6    Vinod Kumar Sharma        75     94     74       81             NaN
# 7     Gulshan Kumar Ray        73     74     83       76            94.0
# 8    Ashutosh Kumar raj        89     70     89       97            81.0
# 9             Amit kumar       80     71     73       79            80.0
# 10          Astha sachan       77     71     77       93            72.0
# 11          Shail Kumari       95     97     80       92            92.0
# ...

# %%
df2['percentage'] = df2['total']/4

# %%
df2
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science  \
# 0          Smriti Ranjan       85     83     93       91            94.0
# 1         Tannu kumari..       90     75     78       73            75.0
# 2                  Seema       93     75     78       89            94.0
# 3        Mukesh Nirmal..       92     71     72       87            78.0
# 4                  rohit       75     78     87       90            87.0
# 5               Ramakant       84     76     75       76            96.0
# 6    Vinod Kumar Sharma        75     94     74       81             NaN
# 7     Gulshan Kumar Ray        73     74     83       76            94.0
# 8    Ashutosh Kumar raj        89     70     89       97            81.0
# 9             Amit kumar       80     71     73       79            80.0
# 10          Astha sachan       77     71     77       93            72.0
# 11          Shail Kumari       95     97     80       92            92.0
# ...

# %%
df2['Grade'] = 'na'

# %%
df2
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science  \
# 0          Smriti Ranjan       85     83     93       91            94.0
# 1         Tannu kumari..       90     75     78       73            75.0
# 2                  Seema       93     75     78       89            94.0
# 3        Mukesh Nirmal..       92     71     72       87            78.0
# 4                  rohit       75     78     87       90            87.0
# 5               Ramakant       84     76     75       76            96.0
# 6    Vinod Kumar Sharma        75     94     74       81             NaN
# 7     Gulshan Kumar Ray        73     74     83       76            94.0
# 8    Ashutosh Kumar raj        89     70     89       97            81.0
# 9             Amit kumar       80     71     73       79            80.0
# 10          Astha sachan       77     71     77       93            72.0
# 11          Shail Kumari       95     97     80       92            92.0
# ...

# %%
df2.loc[df2['percentage']>=90, ['Grade']] = 'Dist'

# %%
df2
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science  \
# 0          Smriti Ranjan       85     83     93       91            94.0
# 1         Tannu kumari..       90     75     78       73            75.0
# 2                  Seema       93     75     78       89            94.0
# 3        Mukesh Nirmal..       92     71     72       87            78.0
# 4                  rohit       75     78     87       90            87.0
# 5               Ramakant       84     76     75       76            96.0
# 6    Vinod Kumar Sharma        75     94     74       81             NaN
# 7     Gulshan Kumar Ray        73     74     83       76            94.0
# 8    Ashutosh Kumar raj        89     70     89       97            81.0
# 9             Amit kumar       80     71     73       79            80.0
# 10          Astha sachan       77     71     77       93            72.0
# 11          Shail Kumari       95     97     80       92            92.0
# ...

# %%
a = pd.DataFrame({'Name':['a','b', 'c','d'], 'Grade':[7, 3, 5, 6]})

# %%
a
# Out:
#   Name  Grade
# 0    a      7
# 1    b      3
# 2    c      5
# 3    d      6

# %%
b = pd.DataFrame({'Name':['a','b', 'c','e'], 'Grade':[7, 3, 5, 9]})
b
# Out:
#   Name  Grade
# 0    a      7
# 1    b      3
# 2    c      5
# 3    e      9

# %%
pd.merge(a,b)
# Out:
#   Name  Grade
# 0    a      7
# 1    b      3
# 2    c      5

# %%
pd.concat([a,b], axis=1, join='inner')
# Out:
#   Name  Grade Name  Grade
# 0    a      7    a      7
# 1    b      3    b      3
# 2    c      5    c      5
# 3    d      6    e      9

# %% [markdown]
# joins

# %%
a.join(b,how='outer', rsuffix='_1')
# Out:
#   Name  Grade Name_1  Grade_1
# 0    a      7      a        7
# 1    b      3      b        3
# 2    c      5      c        5
# 3    d      6      e        9
