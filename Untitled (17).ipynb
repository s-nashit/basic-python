# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics

# %%
sns.set()

# %%
iris = pd.read_csv('D:\OJT-AI, W4\Iris.csv')

# %%
iris.head(10)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa
# 5            5.4           3.9            1.7           0.4  Iris-setosa
# 6            4.6           3.4            1.4           0.3  Iris-setosa
# 7            5.0           3.4            1.5           0.2  Iris-setosa
# 8            4.4           2.9            1.4           0.2  Iris-setosa
# 9            4.9           3.1            1.5           0.1  Iris-setosa

# %%
iris.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.3+ KB

# %%
#Statical concepts

iris.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # Statical values
#
# * count
# * mean (mathematical average)
# * standard deviation
# * minimum
# * maximum
# * IQR - Inter Quartile Range
#
# ** Min, Max, Outliers
# * 68 71 75 79 74 76 78 72 73 ....   outliers =  "97"/"47"
# min = 68
# max = 79
# half = Median - 50% - 74.98
#
# * lower quartile = min to half =  68, 71, 74, 73, 72 , ...., 74.98 - 25%
# * upper = half to max =  74.98, 75, 79, 78, 76, .... - 75%

# %%
iris.isna()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            False         False          False         False    False
# 1            False         False          False         False    False
# 2            False         False          False         False    False
# 3            False         False          False         False    False
# 4            False         False          False         False    False
# ..             ...           ...            ...           ...      ...
# 145          False         False          False         False    False
# 146          False         False          False         False    False
# 147          False         False          False         False    False
# 148          False         False          False         False    False
# 149          False         False          False         False    False
#
# [150 rows x 5 columns]

# %%
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %% [markdown]
# # Visualization
# * UNIVARIATE

# %%
plt.hist(iris['Species'])
plt.show()

# %% [markdown]
# ## each species has 50 samples
# # evenly balanced

# %%
print(iris.shape)
# Out:
# (128, 5)

# %%
plt.hist(iris['PetalWidthCm'])
plt.show()

# %% [markdown]
# * bivariate analysis -

# %%
plt.figure(figsize=(9,7))

sns.scatterplot(iris['SepalLengthCm'], iris['SepalWidthCm'], hue = iris['Species'])
plt.title('Sepal width vs Sepal Length')
# Out:
# c:\users\nashit\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Sepal width vs Sepal Length')

# %% [markdown]
# * setosa - sepal_length = low, sepal_width = high
# * versicolor - sepal_length = mid, sepal_width = mid
# * virginica - sepal_length = high, sepal_width = low

# %% [markdown]
# plt.figure(figsize=(9,7))
#
# sns.scatterplot(iris['PetalLengthCm'], iris['PetalWidthCm'], hue = iris['Species'])
# plt.title('Petal width vs Petal Length')

# %%
plt.figure(figsize=(9,5))

sns.scatterplot(iris['PetalLengthCm'], iris['PetalWidthCm'], hue = iris['Species'])
plt.title('Petal width vs Petal Length')
# Out:
# c:\users\nashit\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Petal width vs Petal Length')

# %% [markdown]
# * setosa - petal length - less, petal width -less
# * versicolor - petal length - mid, petal width - mid
# * virginica - petal length - big, petal width - big

# %%
#pairplot

plt.figure(figsize=(9,5))
sns.pairplot(data = iris, hue = 'Species')

# %% [markdown]
# #insights
# * setosa has small petals (l/w)
# * versicolor has medium petals
# * virginica has large petals
# ** high correlation

# %%
iris.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
plt.figure(figsize = (7,7))
sns.heatmap(iris.corr(), annot = True)
plt.plot()
# Out:
# []

# %% [markdown]
# * petal  length & width have very high positive correlation
# * sepal  length & width have slight correlation

# %%
sns.boxplot(iris['SepalLengthCm'])
# Out:
# c:\users\nashit\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SepalLengthCm'>

# %%
sns.boxplot(iris['SepalWidthCm'])
# Out:
# c:\users\nashit\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SepalWidthCm'>

# %%
sns.boxplot(iris['PetalLengthCm'])
# Out:
# c:\users\nashit\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PetalLengthCm'>

# %%
sns.boxplot(iris['PetalWidthCm'])
# Out:
# c:\users\nashit\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PetalWidthCm'>

# %%
fig, axes = plt.subplots(2, 2, figsize=(12,7))
sns.boxplot( y ='PetalWidthCm', x = 'Species', data = iris, orient = 'v', ax = axes[0,0])
sns.boxplot( y ='SepalLengthCm', x = 'Species', data = iris, orient = 'v', ax = axes[0,1])
sns.boxplot( y ='SepalWidthCm', x = 'Species', data = iris, orient = 'v', ax = axes[1,0])
sns.boxplot( y ='PetalLengthCm', x = 'Species', data = iris, orient = 'v', ax = axes[1,1])
plt.show()

# %%
sns.boxplot( y ='SepalLengthCm', x = 'Species', data = iris,orient = 'v', axes = [0,1])
sns.boxplot( y ='SepalWidthCm', x = 'Species', data = iris,orient = 'v', axes = [1,0])
sns.boxplot( y ='PetalLengthCm', x = 'Species', data = iris,orient = 'v', axes = [1,1])

# %%
print(np.where(iris['SepalWidthCm']>4))
print(np.where(iris['SepalWidthCm']<2.1))
# Out:
# (array([], dtype=int32),)
# (array([52], dtype=int32),)

# %%
Q1 = np.percentile(iris['SepalWidthCm'], 25, interpolation = 'midpoint')
Q3 = np.percentile(iris['SepalWidthCm'], 75, interpolation = 'midpoint')
IQR = Q3-Q1

# %%
print(iris.shape)
# Out:
# (128, 5)

# %%
upper = np.where(iris['SepalWidthCm'] >= (Q3+1.5*IQR))

# %%
lower = np.where(iris['SepalWidthCm'] <= (Q3-1.5*IQR))

# %%
iris.drop(upper[0], inplace = True)

# %%
print(iris.shape)
# Out:
# (128, 5)
