# %%
#Data Mining
import pandas as pd

df = pd.read_csv('insa.csv')
df
# Out:
#                  State/District  ITI Count  Trade Count  Seat Count Current  \
# 0   ANDAMAN AND NICOBAR ISLANDS          4         15.0                 608
# 1                ANDHRA PRADESH        514         54.0               59716
# 2             ARUNACHAL PRADESH          7         28.0                 964
# 3                         ASSAM         42         38.0                4408
# 4                         BIHAR       1370          NaN              114672
# 5                    CHANDIGARH          2         29.0                1012
# 6                  CHHATTISGARH        233         51.0               26892
# 7        DADRA AND NAGAR HAVELI          0          0.0                   0
# 8                 DAMAN AND DIU          0          0.0                   0
# 9                         DELHI         53         63.0               11844
# 10                        ASSAM         42         38.0                4408
#
#     Trainee Count
# 0           531.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State/District      11 non-null     object
#  1   ITI Count           11 non-null     int64
#  2   Trade Count         10 non-null     float64
#  3   Seat Count Current  11 non-null     int64
#  4   Trainee Count       8 non-null      float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 572.0+ bytes

# %%
df.isnull().any()
# Out:
# State/District        False
# ITI Count             False
# Trade Count            True
# Seat Count Current    False
# Trainee Count          True
# dtype: bool

# %%
#drop the rows
df.dropna(inplace=True)

# %%
df
# Out:
#                  State/District  ITI Count  Trade Count  Seat Count Current  \
# 0   ANDAMAN AND NICOBAR ISLANDS          4         15.0                 608
# 2             ARUNACHAL PRADESH          7         28.0                 964
# 3                         ASSAM         42         38.0                4408
# 5                    CHANDIGARH          2         29.0                1012
# 6                  CHHATTISGARH        233         51.0               26892
# 7        DADRA AND NAGAR HAVELI          0          0.0                   0
# 9                         DELHI         53         63.0               11844
# 10                        ASSAM         42         38.0                4408
#
#     Trainee Count
# 0           531.0
# 2           487.0
# 3          3500.0
# 5           910.0
# 6         21996.0
# 7             0.0
# 9          8774.0
# 10         3500.0

# %%
df
# Out:
#                  State/District  ITI Count  Trade Count  Seat Count Current  \
# 0   ANDAMAN AND NICOBAR ISLANDS          4         15.0                 608
# 1                ANDHRA PRADESH        514         54.0               59716
# 2             ARUNACHAL PRADESH          7         28.0                 964
# 3                         ASSAM         42         38.0                4408
# 4                         BIHAR       1370          NaN              114672
# 5                    CHANDIGARH          2         29.0                1012
# 6                  CHHATTISGARH        233         51.0               26892
# 7        DADRA AND NAGAR HAVELI          0          0.0                   0
# 8                 DAMAN AND DIU          0          0.0                   0
# 9                         DELHI         53         63.0               11844
# 10                        ASSAM         42         38.0                4408
#
#     Trainee Count
# 0           531.0
# ...

# %%
a = df.fillna(999999999)

# %%
a
# Out:
#                  State/District  ITI Count  Trade Count  Seat Count Current  \
# 0   ANDAMAN AND NICOBAR ISLANDS          4         15.0                 608
# 1                ANDHRA PRADESH        514         54.0               59716
# 2             ARUNACHAL PRADESH          7         28.0                 964
# 3                         ASSAM         42         38.0                4408
# 4                         BIHAR       1370  999999999.0              114672
# 5                    CHANDIGARH          2         29.0                1012
# 6                  CHHATTISGARH        233         51.0               26892
# 7        DADRA AND NAGAR HAVELI          0          0.0                   0
# 8                 DAMAN AND DIU          0          0.0                   0
# 9                         DELHI         53         63.0               11844
# 10                        ASSAM         42         38.0                4408
#
#     Trainee Count
# 0           531.0
# ...

# %%
med = df['Trainee Count'].median()

# %%
df['Trainee Count'].fillna(med, inplace=True)

# %%
df
# Out:
#                  State/District  ITI Count  Trade Count  Seat Count Current  \
# 0   ANDAMAN AND NICOBAR ISLANDS          4         15.0                 608
# 1                ANDHRA PRADESH        514         54.0               59716
# 2             ARUNACHAL PRADESH          7         28.0                 964
# 3                         ASSAM         42         38.0                4408
# 4                         BIHAR       1370          NaN              114672
# 5                    CHANDIGARH          2         29.0                1012
# 6                  CHHATTISGARH        233         51.0               26892
# 7        DADRA AND NAGAR HAVELI          0          0.0                   0
# 8                 DAMAN AND DIU          0          0.0                   0
# 9                         DELHI         53         63.0               11844
# 10                        ASSAM         42         38.0                4408
#
#     Trainee Count
# 0           531.0
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                 State/District  ITI Count  Trade Count  Seat Count Current  \
# 0  ANDAMAN AND NICOBAR ISLANDS          4         15.0                 608
# 1               ANDHRA PRADESH        514         54.0               59716
# 2            ARUNACHAL PRADESH          7         28.0                 964
# 3                        ASSAM         42         38.0                4408
# 4                        BIHAR       1370          NaN              114672
# 5                   CHANDIGARH          2         29.0                1012
# 6                 CHHATTISGARH        233         51.0               26892
# 7       DADRA AND NAGAR HAVELI          0          0.0                   0
# 8                DAMAN AND DIU          0          0.0                   0
# 9                        DELHI         53         63.0               11844
#
#    Trainee Count
# 0          531.0
# 1         2205.0
# 2          487.0
# 3         3500.0
# 4         2205.0
# 5          910.0
# ...

# %%
from ydata_profiling import ProfileReport

# %%
hello = ProfileReport(df)

# %%
hello.to_file('nashit.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
hello.to_file('nashit.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
