# %%
import pandas as pd
df = pd.read_csv('dia.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.sample()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 523            9      130             70              0        0  34.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 523                     0.652   45        1

# %%
x = df.drop('Outcome', axis='columns')

# %%
x.sample()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 572            3      111             58             31       44  29.5
#
#      DiabetesPedigreeFunction  Age
# 572                      0.43   22

# %%
feature_col= ['Pregnencies', 'Glucose', 'BloodPressure','SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']

# %%
y = df['Outcome']

# %%
#Split
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
x_train.shape
# Out:
# (576, 8)

# %%
x_test.shape
# Out:
# (192, 8)

# %%
#Model
from  import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predicted_value=model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.7395833333333334

# %%
from sklearn import metrics

# %%
metrics.accuracy_score(y_test,predicted_value)
# Out:
# 0.7395833333333334

# %%
import pydotplus

# %%
from sklearn.tree import export_graphviz

# %%
from six import StringIO

# %%
from IPython.display import Image

# %%
dot_data = StringIO()
import cv2
from PIL import Image

# %%
export_graphviz(model, out_file=a_data, filled=True, rounded=True, feature_names=feature_col)
graph = pydotplus.graph_from_dot_data(a_data.getvalue())
cv2.imwrite("graph.png", graph)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[91], line 3
#       1 export_graphviz(model, out_file=a_data, filled=True, rounded=True, feature_names=feature_col)
#       2 graph = pydotplus.graph_from_dot_data(a_data.getvalue())
# ----> 3 cv2.imwrite("graph.png", graph)
#
# error: OpenCV(4.8.1) :-1: error: (-5:Bad argument) in function 'imwrite'
# > Overload resolution failed:
# >  - img is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'img'

# %%
graph.write_png('aaa.png')
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 graph.write_png('aaa.png')
#       2 Image(graph.create_png())
#
# AttributeError: 'list' object has no attribute 'write_png'

# %%
import matplotlib.pyplot as plt
from sklearn import tree
feature_col= ['Pregnencies', 'Glucose', 'BloodPressure','SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
plt.figure(figsize=(15,10))
a = tree.plot_tree(model,feature_names=feature_col,filled=True)
plt.savefig('dia', dpi=1000)
