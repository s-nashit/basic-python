# %%
import matplotlib.pyplot as plt

x1 = [2, 5, 6]
y1 = [3, 9, 5]

x2 = [9, 5, 7]
y2 = [4, 3, 1]

plt.plot(x1,y1)
plt.plot(x2,y2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

a = plt.figure()
ax = plt.axes(projection = '3d')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

a = plt.figure()
ax = plt.axes(projection = '3d')

x = (1,  5, 9, 7)
y = (2, 8 , 7 , 3)
z = (7, 5, 4 , 2)

ax.plot3D(x, y, z, 'red')

plt.show()
